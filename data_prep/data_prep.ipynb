# %%
import pandas as pd
import numpy as np

# %%
df_rl = pd.read_csv('../Selected_features.csv')

# %%
df_rl.head()
# Out:
#    Unnamed: 0  Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  Pkt_Len_Mean  \
# 0           0        1038667             2             0      0.000000
# 1           1        1173584             5             1    561.714286
# 2           2         537442             4             5    393.200000
# 3           3            250             2             0      0.000000
# 4           4            247             2             0      0.000000
#
#    Flow_Byts/s  ACK_Flag_Cnt  Init_Fwd_Win_Byts  SYN_Flag_Cnt  label  \
# 0     0.000000             0              29200             2      1
# 1  3350.420592             4              29200             3      1
# 2  7316.138300             9                137             0      1
# 3     0.000000             2                183             0      1
# 4     0.000000             2                183             0      1
#
#    syn_ratio
# 0        1.0
# 1        0.5
# 2        0.0
# 3        0.0
# 4        0.0

# %%
df_rl.columns
# Out:
# Index(['Unnamed: 0', 'Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts',
#        'Pkt_Len_Mean', 'Flow_Byts/s', 'ACK_Flag_Cnt', 'Init_Fwd_Win_Byts',
#        'SYN_Flag_Cnt', 'label', 'syn_ratio'],
#       dtype='object')

# %%
df_rl[[
    "Flow_Duration", "Tot_Fwd_Pkts", "Tot_Bwd_Pkts",
    "Pkt_Len_Mean", "Flow_Byts/s", "ACK_Flag_Cnt",
    "Init_Fwd_Win_Byts", "SYN_Flag_Cnt", "syn_ratio"
]].describe()
# Out:
#        Flow_Duration   Tot_Fwd_Pkts   Tot_Bwd_Pkts   Pkt_Len_Mean  \
# count   2.078390e+05  207839.000000  207839.000000  207839.000000
# mean    5.837404e+06      23.838529       0.212222       1.902292
# std     6.679984e+06    2600.970567       1.457202      20.967601
# min     0.000000e+00       1.000000       0.000000       0.000000
# 25%     1.051900e+06       2.000000       0.000000       0.000000
# 50%     7.186406e+06       4.000000       0.000000       0.000000
# 75%     7.215634e+06       4.000000       0.000000       0.000000
# max     1.199998e+08  341279.000000     385.000000    1216.666667
#
#         Flow_Byts/s   ACK_Flag_Cnt  Init_Fwd_Win_Byts   SYN_Flag_Cnt  \
# count  2.078380e+05  207839.000000      207839.000000  207839.000000
# mean   3.631781e+04       0.728068       22635.372995       2.991234
# std    6.978005e+05       2.877529       12101.417918       1.748331
# min    0.000000e+00       0.000000           0.000000       0.000000
# 25%    0.000000e+00       0.000000       29200.000000       2.000000
# 50%    0.000000e+00       0.000000       29200.000000       4.000000
# 75%    0.000000e+00       1.000000       29200.000000       4.000000
# max    6.000000e+07     769.000000       64998.000000      14.000000
#
#            syn_ratio
# count  207839.000000
# mean        0.750180
# std         0.424147
# min         0.000000
# 25%         0.500000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df_rl["Flow_Duration_bin"] = pd.qcut(
    df_rl["Flow_Duration"],
    q=5,
    labels=False,
    duplicates="drop"
)

# %%
df_rl["Tot_Fwd_Pkts_bin"] = pd.cut(
    df_rl["Tot_Fwd_Pkts"],
    bins=[-1, 1, 3, 10, 100, 1000, float("inf")],
    labels=False
)

# %%
df_rl["Tot_Bwd_Pkts_bin"] = pd.cut(
    df_rl["Tot_Bwd_Pkts"],
    bins=[-1, 0, 1, 5, 50, float("inf")],
    labels=False
)

# %%
df_rl["Pkt_Len_Mean_bin"] = pd.cut(
    df_rl["Pkt_Len_Mean"],
    bins=[-0.1, 0.1, 200, 800, float("inf")],
    labels=False
)

# %%
df_rl["Flow_Bytes_s_bin"] = pd.qcut(
    df_rl["Flow_Byts/s"],
    q=5,
    labels=False,
    duplicates="drop"
)

# %%
df_rl["ACK_Flag_Cnt_bin"] = pd.cut(
    df_rl["ACK_Flag_Cnt"],
    bins=[-1, 0, 1, 3, 10, float("inf")],
    labels=False
)

# %%
df_rl["Init_Fwd_Win_Byts_bin"] = pd.qcut(
    df_rl["Init_Fwd_Win_Byts"],
    q=5,
    labels=False,
    duplicates="drop"
)

# %%
df_rl["SYN_Flag_Cnt_bin"] = pd.cut(
    df_rl["SYN_Flag_Cnt"],
    bins=[-1, 0, 1, 3, 5, 10, float("inf")],
    labels=False
)

# %%
df_rl["syn_ratio_bin"] = pd.cut(
    df_rl["syn_ratio"],
    bins=[-0.01, 0.01, 0.5, 0.9, 1.0, 1.01],
    labels=False
)

# %%
bin_cols = [
    "Flow_Duration_bin",
    "Tot_Fwd_Pkts_bin",
    "Tot_Bwd_Pkts_bin",
    "Pkt_Len_Mean_bin",
    "Flow_Bytes_s_bin",
    "ACK_Flag_Cnt_bin",
    "Init_Fwd_Win_Byts_bin",
    "SYN_Flag_Cnt_bin",
    "syn_ratio_bin",
    "label"
]

df_bins = df_rl[bin_cols].copy()

# %%
df_bins
# Out:
#         Flow_Duration_bin  Tot_Fwd_Pkts_bin  Tot_Bwd_Pkts_bin  \
# 0                       1                 1                 0
# 1                       1                 2                 1
# 2                       1                 2                 2
# 3                       0                 1                 0
# 4                       0                 1                 0
# ...                   ...               ...               ...
# 207834                  3                 2                 0
# 207835                  3                 2                 0
# 207836                  4                 2                 0
# 207837                  4                 2                 0
# 207838                  1                 2                 0
#
#         Pkt_Len_Mean_bin  Flow_Bytes_s_bin  ACK_Flag_Cnt_bin  \
# 0                      0               0.0                 0
# 1                      2               0.0                 3
# 2                      2               0.0                 3
# 3                      0               0.0                 2
# 4                      0               0.0                 2
# ...                  ...               ...               ...
# 207834                 0               0.0                 0
# 207835                 0               0.0                 0
# 207836                 0               0.0                 0
# 207837                 0               0.0                 0
# 207838                 0               0.0                 0
#
#         Init_Fwd_Win_Byts_bin  SYN_Flag_Cnt_bin  syn_ratio_bin  label
# 0                           1                 2              3      1
# 1                           1                 2              1      1
# 2                           0                 0              0      1
# 3                           0                 0              0      1
# 4                           0                 0              0      1
# ...                       ...               ...            ...    ...
# 207834                      1                 3              3      0
# 207835                      1                 3              3      0
# 207836                      1                 3              3      0
# 207837                      1                 3              3      0
# 207838                      1                 3              3      0
#
# [207839 rows x 10 columns]

# %%
df_bins.to_csv("../Binerized_features.csv")
